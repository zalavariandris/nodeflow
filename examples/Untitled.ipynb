# %%
import numpy as np

# %%
R, G = np.mgrid[0:255:720j, 0:255:1280j].astype(np.uint8)
B = np.zeros(shape=R.shape, dtype=np.uint8)
rgb = np.dstack([R, G, B])
import matplotlib.pyplot as plt
plt.imshow(rgb)
